# %%
import pandas as pd
pd.plotting.register_matplotlib_converters()
import matplotlib.pyplot as plt
# %matplotlib inline
import seaborn as sns
print("Setup Complete")
# Out:
# Setup Complete

# %%
museum_data = pd.read_csv('Museum_Visitors.csv')
museum_data.head()
museum_data['Month'] = pd.to_datetime(museum_data.Month)
museum_data.dtypes
# Out:
# Month                                   datetime64[ns]
# America Tropical Interpretive Center             int64
# Avila Adobe                                      int64
# Chinese American Museum                          int64
# Gateway to Nature Center                       float64
# Firehouse Museum                                 int64
# Hellman Quon                                   float64
# IAMLA                                          float64
# Pico House                                     float64
# Visitor Center/ El Tranquilo Gallery           float64
# Museum of Social Justice                       float64
# Biscailuz Gallery                              float64
# dtype: object

# %%
plt.figure(figsize=(18,6))
plt.title("Monthly Visitors to Avila Adobe")
sns.lineplot(data=museum_data['Avila Adobe'])
plt.xlabel("Date")
# Out:
# Text(0.5, 0, 'Date')
